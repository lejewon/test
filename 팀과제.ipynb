# %% [markdown]
# ## 7. 아래의 리스트는 특허청 사이트에서 니스(NICE)국제상품분류 악기 페이지에 나와있는 일부의 악기들을 적어놓은 리스트이다. 악기의 이름을 적었을 때 악기가 리스트에서 몇 번째에 있는지 알려주고 그 나온 숫자를 이용하여 악기를 리스트에서 삭제하는 함수를 만든뒤,만든 함수를 이용하여 배럴 오르간이라는 악기를 삭제하시오.(7조 임선민,박상헌)
#
# ```
# instrument_list = ['가야금','거문고','고적대 지휘봉','구금','구멍뚫린 두루마리악보','금관악기','기계식 피아노','기타','기타 새들','기타 이펙터','기타 전용 커버','기타용 어깨끈','기타용 카포','기타용 피크','기타줄,꽹과리','단소','대금','대나무 플루트','더블바순','더블베이스','더블베이스용 각봉','덜시머','동양식 하프','드럼 및 타악기','드럼 연습용 패드','드럼','드럼','드럼머신','드럼용 가죽','드럼채','디지털 피아노','래틀','로봇식 드럼','류트','리드','리라','리코더','마림바','만돌라','만돌린','멜로디언','멜로디카','목관악기','목관악기 마우스피스용 리드','목금','뮤직 신시사이저','뮤직박스','바순','바이올린','바이올린 턱받침','반도니온','발랄라이카','배럴 오르간','백파이프','밴조','벅신','베이스','베이스기타','벨달린 모자','보면대','봉고 드럼','북','북용 가죽','북채','비올라','비파','색소폰','셍','소리굽쇠','수직형 대나무 피리','수직형 대나무 피리','슈오나','스네어드럼','스네어드럼용 스네어와이어','스틸드럼','심벌즈']```

# %% [markdown]
# # 이게 원래 답인데, 커멘트에 달린대로, 삭제하는 부분을 다른 곳에서 처리하도록
# # 수정해보세요.

# %%
instrument_list = ['가야금','거문고','고적대 지휘봉','구금','구멍뚫린 두루마리악보','금관악기','기계식 피아노','기타','기타 새들','기타 이펙터','기타 전용 커버','기타용 어깨끈','기타용 카포','기타용 피크','기타줄,꽹과리','단소','대금','대나무 플루트','더블바순','더블베이스','더블베이스용 각봉','덜시머','동양식 하프','드럼 및 타악기','드럼 연습용 패드','드럼','드럼','드럼머신','드럼용 가죽','드럼채','디지털 피아노','래틀','로봇식 드럼','류트','리드','리라','리코더','마림바','만돌라','만돌린','멜로디언','멜로디카','목관악기','목관악기 마우스피스용 리드','목금','뮤직 신시사이저','뮤직박스','바순','바이올린','바이올린 턱받침','반도니온','발랄라이카','배럴 오르간','백파이프','밴조','벅신','베이스','베이스기타','벨달린 모자','보면대','봉고 드럼','북','북용 가죽','북채','비올라','비파','색소폰','셍','소리굽쇠','수직형 대나무 피리','수직형 대나무 피리','슈오나','스네어드럼','스네어드럼용 스네어와이어','스틸드럼','심벌즈']

def word_remove(n):   
    word_idx = instrument_list.index(n)    
    word_del = instrument_list.pop(word_idx) 
    print('{} 이라는 악기는 {}번째에 위치하였습니다'.format(word_del,word_idx)) 
    if instrument_list[word_idx] != word_del : 
      print('instrument_list에 있는 {} 를(을) 제거 했습니다. '.format(n))
    return instrument_list

# %%
word_remove('가야금')
# Out:
# 가야금 이라는 악기는 0번째에 위치하였습니다
# instrument_list에 있는 가야금 를(을) 제거 했습니다.
# ['거문고',
#  '고적대 지휘봉',
#  '구금',
#  '구멍뚫린 두루마리악보',
#  '금관악기',
#  '기계식 피아노',
#  '기타',
#  '기타 새들',
#  '기타 이펙터',
#  '기타 전용 커버',
#  '기타용 어깨끈',
#  '기타용 카포',
#  '기타용 피크',
#  '기타줄,꽹과리',
#  '단소',
#  '대금',
#  '대나무 플루트',
#  '더블바순',
#  '더블베이스',
#  '더블베이스용 각봉',
#  '덜시머',
#  '동양식 하프',
#  '드럼 및 타악기',
#  '드럼 연습용 패드',
#  '드럼',
#  '드럼',
#  '드럼머신',
#  '드럼용 가죽',
#  '드럼채',
#  '디지털 피아노',
#  '래틀',
#  '로봇식 드럼',
#  '류트',
#  '리드',
#  '리라',
#  '리코더',
#  '마림바',
#  '만돌라',
#  '만돌린',
#  '멜로디언',
#  '멜로디카',
#  '목관악기',
#  '목관악기 마우스피스용 리드',
#  '목금',
#  '뮤직 신시사이저',
#  '뮤직박스',
#  '바순',
#  '바이올린',
#  '바이올린 턱받침',
#  '반도니온',
#  '발랄라이카',
#  '배럴 오르간',
#  '백파이프',
#  '밴조',
#  '벅신',
#  '베이스',
#  '베이스기타',
#  '벨달린 모자',
#  '보면대',
#  '봉고 드럼',
#  '북',
#  '북용 가죽',
#  '북채',
#  '비올라',
#  '비파',
#  '색소폰',
#  '셍',
#  '소리굽쇠',
#  '수직형 대나무 피리',
#  '수직형 대나무 피리',
#  '슈오나',
#  '스네어드럼',
#  '스네어드럼용 스네어와이어',
#  '스틸드럼',
#  '심벌즈']
